# %%
import os
import re
import numpy as np
import pandas as pd
import gensim
import collections
from nltk.corpus import stopwords
import nltk

import json

from sqlalchemy import create_engine
from sqlalchemy_utils import create_database, database_exists, drop_database
import psycopg2
from psycopg2.extensions import ISOLATION_LEVEL_AUTOCOMMIT
# Out:
# /home/clutch/anaconda3/envs/insight/lib/python3.7/site-packages/sqlalchemy/sql/functions.py:68: SAWarning: The GenericFunction 'array_agg' is already registered and is going to be overriden.
#   "is going to be overriden.".format(identifier))

# %%
# using function from "Keeping API Keys Secret.ipynb"
# by https://github.com/dylburger
def get_file_contents(filename):
    """ 
    Given a filename,
    return the contents of that file
    """
    try:
        with open(filename, 'r') as f:
            # assumed file is a single line with key
            return f.read().strip()
    except FileNotFoundError:
        print("'%s' file not found" % filename)

# %%
# Define a database name (we're using a dataset on births, so we'll call it birth_db)
# Set your postgres username
dbname = 'insight_db'
username = 'postgres' # change this to your username
password = get_file_contents('../keys/psql_key')

# %%
# 'engine' is a connection to a database
engine = create_engine('postgres://%s:%s@localhost/%s'%(username,password,dbname))
# load sql_magic so we can write SQL in Jupyter Notebooks
# %load_ext sql_magic

# setup SQL connection to the postgreSQL engine we created
# %config SQL.conn_name = 'engine'
print(engine.url)
# Out:
# postgres://postgres:postgres@localhost/insight_db

# %%
# if a PostgreSQL database with this name exists  
# create a database (if it doesn't exist)
if not database_exists(engine.url):
    # create empty PostgreSQL database
    create_database(engine.url)
print(database_exists(engine.url))
# Out:
# True

# %%
# connect to make queries using psycopg2
con = psycopg2.connect(database = dbname, host = 'localhost', user = username, password = password)
con.set_isolation_level(ISOLATION_LEVEL_AUTOCOMMIT)

# %%
sql_create_table = """
CREATE TABLE comments (
    id SERIAL PRIMARY KEY,
    video_id VARCHAR(255) NOT NULL,
    cid VARCHAR(255) NOT NULL,
    author TEXT,
    text TEXT,
    time TEXT,
    clikes INT, 
    cdislikes INT);
"""

# %%
# create a new cursor object
cur = con.cursor()
# execute the create table statement
cur.execute(sql_create_table)

# %%
# collected paths to video files
# videos, thumbnails, descriptions, subtitles
comments_path_list = []

for root, dirs, files in os.walk("../get_youtube_comments/"):
    for file in files:
        if file.endswith(".comments"): # comments
             comments_path_list.append(os.path.join(root, file))
#comments_path_list[:5]

# %%
def parse_values(path_list):
    """
    input a list of paths to text files
    returns a list of strings without vtt formatting
    """
    video_ids = []
    for i,path in enumerate(path_list):
        f = open(path, 'r',encoding='UTF-8') 
        # split folders
        split_path = path.split(sep='/')
        comments_fname = split_path.pop(-1)
        # split features
        vidx = comments_fname.rfind('.')
        video_ids.append(comments_fname[:vidx])
    return video_ids

# %%
video_ids = parse_values(comments_path_list)
#print(video_ids[:10])

# %%
def insertFromDict(table, dict):
    """Take dictionary object dict and produce sql for 
    inserting it into the named table"""
    sql = 'INSERT INTO ' + table
    sql += ' ('
    sql += ', '.join(dict)
    sql += ') VALUES ('
    sql += ', '.join(map(dictValuePad, dict))
    sql += ');'
    return sql

def dictValuePad(key):
    return '%(' + str(key) + ')s'

# %%
import ast
for i,path in enumerate(comments_path_list):
    c_file = open(path, 'r',encoding='UTF-8')
    for line in c_file.readlines():
        line = line.strip()
        line = ast.literal_eval(line)
        line.update({'video_id':video_ids[i]})
        sql = insertFromDict("comments", line)
        cur.execute(sql, line)

# %% [markdown]
# ### End of creating Comments table and importing video comments

# %%
sql = "SELECT videos.title AS title, * \
       FROM comments INNER JOIN videos \
       ON videos.video_id = comments.video_id"

# %%
import pandas as pd

#data_df = pd.read_sql('SELECT * from comments', con=con)
data_df = pd.read_sql(sql, con=con)

# %%
data_df['text'] = data_df.text.apply(str)

# %%
data_df.drop(['cid', 'author', 'time', 'clikes', 'cdislikes', 'id', 'upload_date', 'video', 'description'], axis=1, inplace=True)

# %%
data_df = data_df.loc[:,~data_df.columns.duplicated()]

# %%
data_df
# Out:
#                                        title     video_id  \
# 0       Build_It_How_to_Build_a_Chicken_Coop  K7tnCDXa-rY
# 1       Build_It_How_to_Build_a_Chicken_Coop  K7tnCDXa-rY
# 2       Build_It_How_to_Build_a_Chicken_Coop  K7tnCDXa-rY
# 3       Build_It_How_to_Build_a_Chicken_Coop  K7tnCDXa-rY
# 4       Build_It_How_to_Build_a_Chicken_Coop  K7tnCDXa-rY
# 5       Build_It_How_to_Build_a_Chicken_Coop  K7tnCDXa-rY
# 6       Build_It_How_to_Build_a_Chicken_Coop  K7tnCDXa-rY
# 7       Build_It_How_to_Build_a_Chicken_Coop  K7tnCDXa-rY
# 8       Build_It_How_to_Build_a_Chicken_Coop  K7tnCDXa-rY
# 9       Build_It_How_to_Build_a_Chicken_Coop  K7tnCDXa-rY
# 10      Build_It_How_to_Build_a_Chicken_Coop  K7tnCDXa-rY
# 11      Build_It_How_to_Build_a_Chicken_Coop  K7tnCDXa-rY
# 12      Build_It_How_to_Build_a_Chicken_Coop  K7tnCDXa-rY
# 13      Build_It_How_to_Build_a_Chicken_Coop  K7tnCDXa-rY
# 14      Build_It_How_to_Build_a_Chicken_Coop  K7tnCDXa-rY
# 15      Build_It_How_to_Build_a_Chicken_Coop  K7tnCDXa-rY
# 16      Build_It_How_to_Build_a_Chicken_Coop  K7tnCDXa-rY
# 17      Build_It_How_to_Build_a_Chicken_Coop  K7tnCDXa-rY
# 18      Build_It_How_to_Build_a_Chicken_Coop  K7tnCDXa-rY
# 19      Build_It_How_to_Build_a_Chicken_Coop  K7tnCDXa-rY
# 20      Build_It_How_to_Build_a_Chicken_Coop  K7tnCDXa-rY
# 21      Build_It_How_to_Build_a_Chicken_Coop  K7tnCDXa-rY
# 22      Build_It_How_to_Build_a_Chicken_Coop  K7tnCDXa-rY
# 23      Build_It_How_to_Build_a_Chicken_Coop  K7tnCDXa-rY
# 24      Build_It_How_to_Build_a_Chicken_Coop  K7tnCDXa-rY
# 25      Build_It_How_to_Build_a_Chicken_Coop  K7tnCDXa-rY
# 26      Build_It_How_to_Build_a_Chicken_Coop  K7tnCDXa-rY
# 27      Build_It_How_to_Build_a_Chicken_Coop  K7tnCDXa-rY
# 28      Build_It_How_to_Build_a_Chicken_Coop  K7tnCDXa-rY
# 29      Build_It_How_to_Build_a_Chicken_Coop  K7tnCDXa-rY
# ...                                      ...          ...
# 252417           How_to_Repair_Plaster_Walls  P4D0sESi5So
# 252418           How_to_Repair_Plaster_Walls  P4D0sESi5So
# 252419           How_to_Repair_Plaster_Walls  P4D0sESi5So
# 252420           How_to_Repair_Plaster_Walls  P4D0sESi5So
# 252421           How_to_Repair_Plaster_Walls  P4D0sESi5So
# 252422           How_to_Repair_Plaster_Walls  P4D0sESi5So
# 252423           How_to_Repair_Plaster_Walls  P4D0sESi5So
# 252424           How_to_Repair_Plaster_Walls  P4D0sESi5So
# 252425           How_to_Repair_Plaster_Walls  P4D0sESi5So
# 252426           How_to_Repair_Plaster_Walls  P4D0sESi5So
# 252427           How_to_Repair_Plaster_Walls  P4D0sESi5So
# 252428           How_to_Repair_Plaster_Walls  P4D0sESi5So
# 252429           How_to_Repair_Plaster_Walls  P4D0sESi5So
# 252430           How_to_Repair_Plaster_Walls  P4D0sESi5So
# 252431           How_to_Repair_Plaster_Walls  P4D0sESi5So
# 252432           How_to_Repair_Plaster_Walls  P4D0sESi5So
# 252433           How_to_Repair_Plaster_Walls  P4D0sESi5So
# 252434           How_to_Repair_Plaster_Walls  P4D0sESi5So
# 252435           How_to_Repair_Plaster_Walls  P4D0sESi5So
# 252436           How_to_Repair_Plaster_Walls  P4D0sESi5So
# 252437           How_to_Repair_Plaster_Walls  P4D0sESi5So
# 252438           How_to_Repair_Plaster_Walls  P4D0sESi5So
# 252439           How_to_Repair_Plaster_Walls  P4D0sESi5So
# 252440           How_to_Repair_Plaster_Walls  P4D0sESi5So
# 252441           How_to_Repair_Plaster_Walls  P4D0sESi5So
# 252442           How_to_Repair_Plaster_Walls  P4D0sESi5So
# 252443           How_to_Repair_Plaster_Walls  P4D0sESi5So
# 252444           How_to_Repair_Plaster_Walls  P4D0sESi5So
# 252445           How_to_Repair_Plaster_Walls  P4D0sESi5So
# 252446           How_to_Repair_Plaster_Walls  P4D0sESi5So
#
#                                                      text        uploader  \
# 0       Discover how to easily build an attractive and...  This_Old_House
# 1       This coop seems to have been designed for huma...  This_Old_House
# 2       You can get more loft to the ceiling with stee...  This_Old_House
# 3                               everyone should follow it  This_Old_House
# 4                                     I love Cottage Shed  This_Old_House
# 5                                                Good Job  This_Old_House
# 6                                          Just implement  This_Old_House
# 7       top secret idea and perfect line included in t...  This_Old_House
# 8                                      Personal implement  This_Old_House
# 9           a single Storage Shed should keep each family  This_Old_House
# 10                                                goooood  This_Old_House
# 11      Chicken wire is insufficient for predator prot...  This_Old_House
# 12      After all these years Tommy can still show me ...  This_Old_House
# 13                  What are the dimensions for this coop  This_Old_House
# 14      Unless I’m mistaken, the cut list for this pro...  This_Old_House
# 15      I like to know how much will build one chicken...  This_Old_House
# 16      nice except that wire wont keep a squirrel out...  This_Old_House
# 17      Did anybody see any vent holes, or was it just...  This_Old_House
# 18                     Any way you guys have a item list?  This_Old_House
# 19      What is the distance between the apex of the g...  This_Old_House
# 20      Oops I forgot to put stardew valley at the start😂  This_Old_House
# 21          Hope it doesn’t leak 🤔 and they were laughing  This_Old_House
# 22           guillotine chicken door .. oops string broke  This_Old_House
# 23          I am 18 I am try really hard but cant do it 😔  This_Old_House
# 24      Using a scrap of linoleum or tin on the floor ...  This_Old_House
# 25      อบสุ่มไก่ด้วยภูมิปัญญาชาวบ้าน\nhttps://youtu.b...  This_Old_House
# 26      Good job, guys. I think it's the right size fo...  This_Old_House
# 27      I love watching professional doing their job, ...  This_Old_House
# 28      The best way to stop predators digging under t...  This_Old_House
# 29      I used to be horrible at building chicken coop...  This_Old_House
# ...                                                   ...             ...
# 252417  i would just remove the lath n plaster and put...  This_Old_House
# 252418                                   thats right..lol  This_Old_House
# 252419  san379 - Yup.  Old Victorian-era homes are a n...  This_Old_House
# 252420  I did a full gut on my house I'm renovating.. ...  This_Old_House
# 252421                                     san379 exactly  This_Old_House
# 252422  Or tear it all off and drywall in the same amo...  This_Old_House
# 252423            @miguel meyers Another taper chimes in!  This_Old_House
# 252424  @9988ScooterGirl How many times have I seen pa...  This_Old_House
# 252425             Division doorway that’s because it is,  This_Old_House
# 252426  darkone12491 dude acts like drywall is for fuc...  This_Old_House
# 252427  JDH Rosewater its just fucking plaster dude relax  This_Old_House
# 252428  Mesh tape doesn't have the same flex as paper ...  This_Old_House
# 252429  +miguel meyers Nice! Exactly what I'd do..and ...  This_Old_House
# 252430  I would do the same but I would mesh tape the ...  This_Old_House
# 252431  Sure - if you want to turn your hand crafted o...  This_Old_House
# 252432  Never remove your plaster. But this is not the...  This_Old_House
# 252433                     Atticus Finch.....no...just no  This_Old_House
# 252434  That would be the best way just have to make s...  This_Old_House
# 252435                                                  👍  This_Old_House
# 252436  hours and thousands of dollars later...  Anyon...  This_Old_House
# 252437  I've done some plaster repair and to be honest...  This_Old_House
# 252438  bluesky As opposed to what method that's faste...  This_Old_House
# 252439                                                 Um  This_Old_House
# 252440          So many sexual innuendos, so little time.  This_Old_House
# 252441  Think I'd have just torn it out. Messy, but pr...  This_Old_House
# 252442               You have clearly never done demo lol  This_Old_House
# 252443  Wrong . Not to mention today's walls are infer...  This_Old_House
# 252444             replaster it in a fraction of this con  This_Old_House
# 252445                                  Absolutely right!  This_Old_House
# 252446  Tear it off and replaster it . Call a real pla...  This_Old_House
#
#         duration  view_count  likes  dislikes  \
# 0            510     1705326   9141       542
# 1            510     1705326   9141       542
# 2            510     1705326   9141       542
# 3            510     1705326   9141       542
# 4            510     1705326   9141       542
# 5            510     1705326   9141       542
# 6            510     1705326   9141       542
# 7            510     1705326   9141       542
# 8            510     1705326   9141       542
# 9            510     1705326   9141       542
# 10           510     1705326   9141       542
# 11           510     1705326   9141       542
# 12           510     1705326   9141       542
# 13           510     1705326   9141       542
# 14           510     1705326   9141       542
# 15           510     1705326   9141       542
# 16           510     1705326   9141       542
# 17           510     1705326   9141       542
# 18           510     1705326   9141       542
# 19           510     1705326   9141       542
# 20           510     1705326   9141       542
# 21           510     1705326   9141       542
# 22           510     1705326   9141       542
# 23           510     1705326   9141       542
# 24           510     1705326   9141       542
# 25           510     1705326   9141       542
# 26           510     1705326   9141       542
# 27           510     1705326   9141       542
# 28           510     1705326   9141       542
# 29           510     1705326   9141       542
# ...          ...         ...    ...       ...
# 252417       247      422502   1688        83
# 252418       247      422502   1688        83
# 252419       247      422502   1688        83
# 252420       247      422502   1688        83
# 252421       247      422502   1688        83
# 252422       247      422502   1688        83
# 252423       247      422502   1688        83
# 252424       247      422502   1688        83
# 252425       247      422502   1688        83
# 252426       247      422502   1688        83
# 252427       247      422502   1688        83
# 252428       247      422502   1688        83
# 252429       247      422502   1688        83
# 252430       247      422502   1688        83
# 252431       247      422502   1688        83
# 252432       247      422502   1688        83
data/build_deck/This_Old_House/Build_It_How_to...       build_deck
# 15      data/build_deck/This_Old_House/Build_It_How_to...       build_deck
# 16      data/build_deck/This_Old_House/Build_It_How_to...       build_deck
# 17      data/build_deck/This_Old_House/Build_It_How_to...       build_deck
# 18      data/build_deck/This_Old_House/Build_It_How_to...       build_deck
# 19      data/build_deck/This_Old_House/Build_It_How_to...       build_deck
# 20      data/build_deck/This_Old_House/Build_It_How_to...       build_deck
# 21      data/build_deck/This_Old_House/Build_It_How_to...       build_deck
# 22      data/build_deck/This_Old_House/Build_It_How_to...       build_deck
# 23      data/build_deck/This_Old_House/Build_It_How_to...       build_deck
# 24      data/build_deck/This_Old_House/Build_It_How_to...       build_deck
# 25      data/build_deck/This_Old_House/Build_It_How_to...       build_deck
# 26      data/build_deck/This_Old_House/Build_It_How_to...       build_deck
# 27      data/build_deck/This_Old_House/Build_It_How_to...       build_deck
# 28      data/build_deck/This_Old_House/Build_It_How_to...       build_deck
# 29      data/build_deck/This_Old_House/Build_It_How_to...       build_deck
# ...                                                   ...              ...
# 252417  data/drywall_repair/This_Old_House/How_to_Repa...   drywall_repair
# 252418  data/drywall_repair/This_Old_House/How_to_Repa...   drywall_repair
# 252419  data/drywall_repair/This_Old_House/How_to_Repa...   drywall_repair
# 252420  data/drywall_repair/This_Old_House/How_to_Repa...   drywall_repair
# 252421  data/drywall_repair/This_Old_House/How_to_Repa...   drywall_repair
# 252422  data/drywall_repair/This_Old_House/How_to_Repa...   drywall_repair
# 252423  data/drywall_repair/This_Old_House/How_to_Repa...   drywall_repair
# 252424  data/drywall_repair/This_Old_House/How_to_Repa...   drywall_repair
# 252425  data/drywall_repair/This_Old_House/How_to_Repa...   drywall_repair
# 252426  data/drywall_repair/This_Old_House/How_to_Repa...   drywall_repair
# 252427  data/drywall_repair/This_Old_House/How_to_Repa...   drywall_repair
# 252428  data/drywall_repair/This_Old_House/How_to_Repa...   drywall_repair
# 252429  data/drywall_repair/This_Old_House/How_to_Repa...   drywall_repair
# 252430  data/drywall_repair/This_Old_House/How_to_Repa...   drywall_repair
# 252431  data/drywall_repair/This_Old_House/How_to_Repa...   drywall_repair
# 252432  data/drywall_repair/This_Old_House/How_to_Repa...   drywall_repair
# 252433  data/drywall_repair/This_Old_House/How_to_Repa...   drywall_repair
# 252434  data/drywall_repair/This_Old_House/How_to_Repa...   drywall_repair
# 252435  data/drywall_repair/This_Old_House/How_to_Repa...   drywall_repair
# 252436  data/drywall_repair/This_Old_House/How_to_Repa...   drywall_repair
# 252437  data/drywall_repair/This_Old_House/How_to_Repa...   drywall_repair
# 252438  data/drywall_repair/This_Old_House/How_to_Repa...   drywall_repair
# 252439  data/drywall_repair/This_Old_House/How_to_Repa...   drywall_repair
# 252440  data/drywall_repair/This_Old_House/How_to_Repa...   drywall_repair
# 252441  data/drywall_repair/This_Old_House/How_to_Repa...   drywall_repair
# 252442  data/drywall_repair/This_Old_House/How_to_Repa...   drywall_repair
# 252443  data/drywall_repair/This_Old_House/How_to_Repa...   drywall_repair
# 252444  data/drywall_repair/This_Old_House/How_to_Repa...   drywall_repair
# 252445  data/drywall_repair/This_Old_House/How_to_Repa...   drywall_repair
# 252446  data/drywall_repair/This_Old_House/How_to_Repa...   drywall_repair
#
# [252447 rows x 11 columns]

# %%
cols = ['video_id', 'title', 'subtitles', 'primary_category']

# %%
comments_merged = pd.DataFrame(data_df.groupby(cols).text.apply(lambda x: ", ".join(x))).reset_index()

# %%
comments_merged['txt_len'] = comments_merged['text'].map(len)

# %%
comments_merged.sort_values(by=['txt_len'], ascending=False)
# Out:
#          video_id                                              title  \
# 586   QA5fh29rhLs  Building_a_Shipping_Container_Home_EP01Permits...
# 113   5f4LisZBCTk          How_to_Attach_a_Beam_to_a_Post_for_a_Deck
# 114   5f4LisZBCTk          How_to_Attach_a_Beam_to_a_Post_for_a_Deck
# 440   K1XmjWDXJn4                     No_Concrete_Fence_Post_Install
# 189   8ci2hj7CSHI     Waterproofing_My_Life_With_FLEX_TAPE_-_JonTron
# 1444  zBCbbXlVOhs                  12_000_HOUSE_-_One_Man_Renovation
# 1393  xMGgQAYOiM0           How_to_Build_an_8_x10_Deck_for_Beginners
# 74    40uCoIgxPC0  This_video_will_piss_off_contractors_-_DO_NOT_...
# 1461  zsob5-HL-TE                   How_To_Install_Laminate_Flooring
# 1460  zsob5-HL-TE                   How_To_Install_Laminate_Flooring
# 235   BJpSFCS64iQ  Log_Cabin_Construction_-_Log_Gable_Ends_Center...
# 504   MvR2pfSdrmw  The_Original_Brown_Paper_Floor_-_DIY_Alternati...
# 501   Mob1K_P_L8U  How_to_Smooth_Out_Uneven_Plaster_With_a_Skim_Coat
# 748   XGUaroWiAMI    Put_Vinegar_On_Your_Plants_And_This_Will_Happen
# 420   JJrNqINzNjM     AMAZING_Way_To_SUPER_CLEAN_The_NASTIEST_Carpet
# 963   flWbt0mHQeU                   How_to_Build_a_Ground_Level_Deck
# 1372  wmRYKrfQjuk  Plywood_Flooring_-_An_inexpensive_alternative_...
# 1373  wmRYKrfQjuk  Plywood_Flooring_-_An_inexpensive_alternative_...
# 27    1_JhhlFFyEE                  Building_a_Covered_Patio_-_Part_1
# 1162  oLZmeHQlBKU  Best_Way_to_tape_and_coat_a_Butt_Joint_in_Dryw...
# 1051  k1XFWNT7pAM      How_to_Pour_a_Concrete_Slab_for_Beginners_DIY
# 384   HQYqe_zzeM4  Most_In-Depth_Wood_American_Flag_Build_Make_Mo...
# 1085  lDEJhqMcgcQ  How_to_Install_Vinyl_Plank_Flooring_Quick_and_...
# 1086  lDEJhqMcgcQ  How_to_Install_Vinyl_Plank_Flooring_Quick_and_...
# 1039  jlKGinWzt3I  BEFORE_and_AFTER_Mobile_Home_REMODEL_of_a_Hoar...
# 689   UuZz7xoXMOc             DIY_How_to_Install_a_Basement_Subfloor
# 440   this video will show some of my experience usi...  repair_wood_fence
# 189   ah I hate it when my computer combusts because...     drywall_repair
# 1444  everyone thanks for joining me hey everyone we...         build_deck
# 1393  hello my name is Craig Heffernan today were go...         build_deck
# 74    [Music] hey whats going on this era Cortina Te...  repair_wood_fence
# 1461  hi Im Jeff from Ottawa design &amp; build Im h...  laminate_flooring
# 1460  hi Im Jeff from Ottawa design &amp; build Im h...    carpet_flooring
# 235   heading down to the little water spot behind t...  repair_wood_fence
# 504   if youre like us and you really like the look ...    carpet_flooring
# 501   let me ask you have you ever had a wall that b...     drywall_repair
# 748   theres a handy ingredient probably sitting in ...  repair_wood_fence
# 420   weve done this for years and it works really w...    carpet_flooring
# 963   hello Im Craig Heffernan from Heffron and cons...         build_deck
# 1372  you okay so Im just going to talk a little bit...    carpet_flooring
# 1373  you okay so Im just going to talk a little bit...  laminate_flooring
# 27    okay so the weather is finally cooling off her...         build_deck
# 1162  I want to show you how to do a bot joint all b...     drywall_repair
# 1051  [Music] [Applause] hi this is David Odell with...         build_deck
# 384   hows it going everyone welcome back to the cha...         build_deck
# 1085  so in todays video we are gonna install a new ...    carpet_flooring
# 1086  so in todays video we are gonna install a new ...  laminate_flooring
# 1039  here we are at my new mobile home piece-of-shi...     drywall_repair
# 689   [Music] so a lot of us in the building industr...    carpet_flooring
# 690   [Music] so a lot of us in the building industr...  laminate_flooring
# 368   this is the instruction manual for this shed t...         build_deck
# 815   hi guys Kirk and J here with Kirk Giordano pla...  repair_wood_fence
# 282   [Music] alright guys welcome back free tip Fri...         build_deck
# ...                                                 ...                ...
# 1152  hi today this video we are going to show you h...  laminate_flooring
# 203   one of the top benefits of laminate wood floor...  laminate_flooring
# 1088  sometimes a hole in a wall will need to be fix...     drywall_repair
# 305   whats up YouTube I got a politician fence here...  repair_wood_fence
# 1347  hello everyone Im Joshua Clement and today Im ...    carpet_flooring
# 592   in this video were going to explain to you how...  repair_wood_fence
# 1238  in this video we will show you how to fit a ca...    carpet_flooring
# 1304  theres a good chance that you could have mold ...  repair_wood_fence
# 39    did I Scott here now whatever the cause kids m...     drywall_repair
# 1178  here are two terrific techniques for making re...     drywall_repair
# 1402  hi cutting carpets into doorways cutting vinyl...    carpet_flooring
# 981   beginning at the straight outer wall John has ...    carpet_flooring
# 1455                                       [Music] you   laminate_flooring
# 237   if youre building a traditional picket fence y...  repair_wood_fence
# 1246  sure tip with you if you have an existing hole...     drywall_repair
# 688   well to the how to install okay so Im doing th...    carpet_flooring
# 921   you know sometimes accidents happen like stepp...    carpet_flooring
# 602   [Music] hey guys onto this video its just to g...    carpet_flooring
# 360   [Music] building a deck from start to finish c...         build_deck
# 603   [Music] hey guys onto this video its just to g...  laminate_flooring
# 428   in this video Im going to provide you with thr...  repair_wood_fence
# 608   Im going to show how to install carpet trim al...    carpet_flooring
# 186   to install your wood floor youll need a cuttin...  laminate_flooring
# 395   and we seem to have wall-to-wall carpeting dow...    carpet_flooring
# 94    in this video were going to learn how to fit a...    carpet_flooring
# 428   Simple yet helpful tip! Thanks man!, You're we...       52
# 608           good job buddy, Thanks!, Yeah!!!, YIPEEE!       41
# 186             Great stuff!, not wood!  Laminate cra p       39
# 395              Nothing to do with carpet installation       38
# 94                  Amazing video thank you for sharing       35
# 758                 Where to find this carpet for sale?       35
# 95                  Amazing video thank you for sharing       35
# 532                         It's only carpet worry wart       27
# 954                               Thank you!, Excellent       21
# 42                                 Beautiful house mate       20
#
# [1467 rows x 6 columns]

# %%
# Import the libraries
import matplotlib.pyplot as plt
import seaborn as sns

# matplotlib histogram
plt.hist(comments_merged['txt_len'], color = 'blue', edgecolor = 'black', bins = 500, )

# seaborn histogram
sns.distplot(comments_merged['txt_len'], hist=True, kde=False, 
             bins=500, color = 'blue',
             hist_kws={'edgecolor':'black'})
# Add labels
plt.title('Histogram of Arrival Delays')
plt.xlabel('??')
plt.ylabel('Length')
# Out:
# Text(0, 0.5, 'Length')

# %%
df_test = pd.DataFrame(comments_merged)

# %%
comments_merged.head()
# Out:
#       video_id                                              title  \
# 0  09Q4JQ3p8yg              How_To_Remove_Popcorn_Stipple_Ceiling
# 1  0Aip_xxpia4                        How_to_Install_Carpet_Tiles
# 2  0AoehDkaA5U  How_to_fix_a_Carpet_to_Wood_floor_Seperator_-_...
# 3  0BYByVuXYJQ                   HOW_TO_INSTALL_LAMINATE_FLOORING
# 4  0COOF3BwgKI  Fix_Small_Nail_Holes_in_Walls_FAST_AND_Make_Th...
#
#                                            subtitles   primary_category  \
# 0  hi Shannon here from health improvements and t...     drywall_repair
# 1  were going to replace this tired old wall-to-w...    carpet_flooring
# 2  so if you just put in carpet or a wood floor y...    carpet_flooring
# 3  my name is Aaron Massey and welcome back to an...  laminate_flooring
# 4  so you like to hang pictures on your wall if y...     drywall_repair
#
#                                                 text  txt_len
# 0  asmr **, I love you, Im here from Instagram lm...    90480
# 1  Interface do a product called tactiles which a...     2183
# 2  Saw another video that said no liquid nails., ...      274
# 3  Keep 'em coming man!, Quantifying in F-Bombs t...     1867
# 4  Glad I could help then.  Be sure and subscribe...     8009

# %%
comments_merged['title']=comments_merged['title'].str.replace('_', ' ')
comments_merged['title']=comments_merged['title'].str.capitalize()

# %%
comments_merged['subtitles']=comments_merged['subtitles'].str.replace('\[Music\]', '')

# %%
comments_merged.head(20)
# Out:
#        video_id                                              title  \
# 0   09Q4JQ3p8yg              How to remove popcorn stipple ceiling
# 1   0Aip_xxpia4                        How to install carpet tiles
# 2   0AoehDkaA5U  How to fix a carpet to wood floor seperator - ...
# 3   0BYByVuXYJQ                   How to install laminate flooring
# 4   0COOF3BwgKI  Fix small nail holes in walls fast and make th...
# 5   0J8q_Lsh4fU                    Hog wire deck rail installation
# 6   0N4ElPIeVgc        Best boat vinyl flooring corner install diy
# 7   0RuwaSU71rY   Replacing a section of drywall after a pipe leak
# 8   0UFO2-Efw7E    Vinyl plank flooring over tile should i do this
# 9   0UtTMhzCpZc  Large plaster repairs skim coating house painting
# 10  0_tvqmF55J0  Diy ceiling repair - skim coat over a painted ...
# 11  0duO9-mAI8Y                                      Deck on steel
# 12  0j4chs3HhoA                            How to skim coat a wall
# 13  0jhqbnM-5XQ        How to make a four season room from a porch
# 14  0rPErZS2yUc                 All car carpets installation guide
# 15  0wIs1KDRfnA     How to build an amazing deck roof - by adaptit
# 16  0yfO96sUXXs             Wood privacy fence picket installation
# 17  17awCvAA7Q0   How to repair a hole in drywall california patch
# 18  1A96fGXS2UM               How to make a patio cooler ice chest
# 19  1D4oA-dkwGc  How to repair drywall damage after baseboards ...
#
#                                             subtitles   primary_category  \
# 0   hi Shannon here from health improvements and t...     drywall_repair
# 1   were going to replace this tired old wall-to-w...    carpet_flooring
# 2   so if you just put in carpet or a wood floor y...    carpet_flooring
# 3   my name is Aaron Massey and welcome back to an...  laminate_flooring
# 4   so you like to hang pictures on your wall if y...     drywall_repair
# 5   hi im paul from Elkins diy.com today Im going ...         build_deck
# 6   well pretend some pretend that this is the nex...    carpet_flooring
# 7   hi Im Mike Thompson last night was a bit of an...     drywall_repair
# 8   hey Jonathan are you doing youre awesome oh yo...  laminate_flooring
# 9    how to patch larger holes now heres where you...     drywall_repair
# 10  okay so weve given this about 15 minutes to se...     drywall_repair
# 11  welcome to deck on Steels light gauge galvaniz...         build_deck
# 12  hi Im Jordan Jones with Bauman and today were ...     drywall_repair
# 13   forty years ago when my house was built scree...         build_deck
# 14  thanks for purchasing carpet from all car carp...    carpet_flooring
# 15  dr. TV stone one-and-only Maddy look at him ga...         build_deck
# 16  hey yeah okay and this part of the fence were ...  repair_wood_fence
# 17  today Im going to teach you how to do a Califo...     drywall_repair
# 18  hey there welcome to DIY projects with Pete Im...         build_deck
# 19  all right so some of my customers got some new...     drywall_repair
#
#                                                  text  txt_len
# 0   asmr **, I love you, Im here from Instagram lm...    90480
# 1   Interface do a product called tactiles which a...     2183
# 2   Saw another video that said no liquid nails., ...      274
# 3   Keep 'em coming man!, Quantifying in F-Bombs t...     1867
# 4   Glad I could help then.  Be sure and subscribe...     8009
# 5   Thanks Naegling, off topic but where are u get...     8102
# 6   What is the name and colour code of that vinyl...      318
# 7   Great Job , Mike Thompson, good instructional ...     4012
# 8   You do NOT have to put down underlayment if yo...    10448
# 9   Good informAtion and tips but incomplete, Hmm....     3265
# 10  Purchase My recommended Tools, Brushes, Paints...     3745
# 11  PLEASE REMOVE THIS VIDEO SINCE YOU ARE OUT OF ...     1479
# 12  Nah 😂😂😂, What a goofy bunch of comments for on...    38604
# 13  Made it look so easy with no gkitches in insta...    40971
# 14  Dam that's harder than it sounds.., How much w...      390
# 15  It's what im looking at the moment. \nCan you ...      988
# 16  Where is the string line to keep the top strai...     4069
# 17  Made a hole in my wall just to try it., @Cliff...    76596
# 18  @sillysausage72 Thanks!!, 2x4's make for solid...    46508
# 19  Oops, I meant to type Thanks*, You make this l...    11307

# %%
to_csv_filename = 'data/csv_files/original_data.csv'

# %%
comments_merged.to_csv(to_csv_filename, sep=',', encoding='utf-8', index=False)

# %%
str1 = df_test[df_test.index=='0AoehDkaA5U'].text
#K7tnCDXa-rY

# %%
for c in str1:
    print(c)
